# %%
# !pip install -q gymnasium shimmy==2.0.0 stable-baselines3[extra] matplotlib opencv-python
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.2/187.2 kB 4.2 MB/s eta 0:00:00

# %%
import numpy as np
import gymnasium as gym
from gymnasium import spaces
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import cv2
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import cv2
import imageio

class WarehouseEnv(gym.Env):
    metadata = {"render_modes": ["rgb_array"], "render_fps": 30}

    def __init__(self, grid_size=10, num_moving_robots=3):
        super().__init__()

        self.grid_size = grid_size
        self.num_moving_robots = num_moving_robots

        # Action space: up, down, left, right
        self.action_space = spaces.Discrete(4)

        self.observation_space = spaces.Box(
            low=0,
            high=grid_size,
            shape=(4,),
            dtype=np.float32,
        )

        self.grid = np.zeros((grid_size, grid_size), dtype=int)

        self._place_shelves()

        self.moving_robots = []
        self.robot_pos = None
        self.goal_pos = None
        self.step_count = 0
        self.max_steps = 200

        self.robot_icon = cv2.imread("robot.png", cv2.IMREAD_UNCHANGED)
        self.shelf_icon = cv2.imread("box.png", cv2.IMREAD_UNCHANGED)
        self.goal_icon = cv2.imread("goal.png", cv2.IMREAD_UNCHANGED)

        self.other_robot_frames = self._load_gif("robotic-arm.gif")
        self.other_robot_frame_index = 0

    def _load_gif(self, path):
        frames = imageio.mimread(path)
        return [cv2.cvtColor(frame, cv2.COLOR_RGBA2BGRA) for frame in frames]

    def _place_shelves(self):
        self.grid[:] = 0
        self.grid[2, 2:8] = 1
        self.grid[5, 1:9] = 1
        self.grid[7, 3:7] = 1

    def _spawn_moving_robots(self):
        self.moving_robots = []
        for _ in range(self.num_moving_robots):
            while True:
                pos = tuple(np.random.randint(0, self.grid_size, size=2))
                if self.grid[pos] == 0:
                    self.moving_robots.append(list(pos))
                    break

    def _move_other_robots(self):
        for i in range(self.num_moving_robots):
            r, c = self.moving_robots[i]

            action = np.random.choice([0, 1, 2, 3])
            if action == 0: r -= 1
            elif action == 1: r += 1
            elif action == 2: c -= 1
            elif action == 3: c += 1

            r = np.clip(r, 0, self.grid_size - 1)
            c = np.clip(c, 0, self.grid_size - 1)

            if self.grid[r, c] == 0:
                self.moving_robots[i] = [r, c]

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)

        self.step_count = 0
        self._spawn_moving_robots()

        while True:
            self.robot_pos = np.random.randint(0, self.grid_size, size=2)
            if self.grid[tuple(self.robot_pos)] == 0 and list(self.robot_pos) not in self.moving_robots:
                break

        while True:
            self.goal_pos = np.random.randint(0, self.grid_size, size=2)
            if self.grid[tuple(self.goal_pos)] == 0 and list(self.goal_pos) not in self.moving_robots:
                break

        obs = np.array([*self.robot_pos, *self.goal_pos], dtype=np.float32)
        return obs, {}

    def step(self, action):

        self._move_other_robots()
        old_pos = self.robot_pos.copy()

        if action == 0: self.robot_pos[0] -= 1
        elif action == 1: self.robot_pos[0] += 1
        elif action == 2: self.robot_pos[1] -= 1
        elif action == 3: self.robot_pos[1] += 1

        self.robot_pos = np.clip(self.robot_pos, 0, self.grid_size - 1)

        if self.grid[tuple(self.robot_pos)] == 1:
            self.robot_pos = old_pos
            reward = -1

        elif list(self.robot_pos) in self.moving_robots:
            self.robot_pos = old_pos
            reward = -5

        else:
            dist = np.linalg.norm(self.robot_pos - self.goal_pos)
            reward = -0.1 * dist

        terminated = False
        truncated = False

        if np.array_equal(self.robot_pos, self.goal_pos):
            reward += 10
            terminated = True

        self.step_count += 1
        if self.step_count >= self.max_steps:
            truncated = True

        obs = np.array([*self.robot_pos, *self.goal_pos], dtype=np.float32)
        return obs, reward, terminated, truncated, {}

    def _overlay_icon(self, base, icon, x, y, w, h):

        icon_resized = cv2.resize(icon, (w, h))

        if icon_resized.shape[2] == 4:  # has alpha channel
            rgb = icon_resized[:, :, :3]
            alpha = icon_resized[:, :, 3] / 255.0

            for c in range(3):
                base[y:y+h, x:x+w, c] = (
                    rgb[:, :, c] * alpha +
                    base[y:y+h, x:x+w, c] * (1 - alpha)
                )
        else:
            base[y:y+h, x:x+w] = icon_resized

    def render(self, mode="rgb_array"):
        img_size = 500
        cell_size = img_size // self.grid_size
        img = np.ones((img_size, img_size, 3), dtype=np.uint8) * 255

        for i in range(self.grid_size):
            for j in range(self.grid_size):
                if self.grid[i, j] == 1:
                    self._overlay_icon(
                        img, self.shelf_icon,
                        j*cell_size, i*cell_size,
                        cell_size, cell_size
                    )

        frame = self.other_robot_frames[self.other_robot_frame_index]
        self.other_robot_frame_index = (self.other_robot_frame_index + 1) % len(self.other_robot_frames)

        for r, c in self.moving_robots:
            self._overlay_icon(
                img, frame,
                c*cell_size, r*cell_size,
                cell_size, cell_size
            )

        r, c = self.robot_pos
        self._overlay_icon(
            img, self.robot_icon,
            c*cell_size, r*cell_size,
            cell_size, cell_size
        )

        gr, gc = self.goal_pos
        self._overlay_icon(
            img, self.goal_icon,
            gc*cell_size, gr*cell_size,
            cell_size, cell_size
        )

        return img

# %%
# === Cell 4: Create vectorized env for training and plain env for eval/visualization ===
def make_env():
    return WarehouseEnv(grid_size=10)

vec_env = DummyVecEnv([make_env])   # for SB3 training
eval_env = WarehouseEnv(grid_size=10)  # plain env for evaluation & visualization

# %%
# === Cell 5: Train PPO ===
model = PPO(
    policy="MlpPolicy",
    env=vec_env,
    learning_rate=3e-4,
    n_steps=1024,
    batch_size=64,
    gae_lambda=0.95,
    gamma=0.99,
    verbose=1,
)

model.learn(total_timesteps=200_000)
model.save("warehouse_ppo_model")
# Out:
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 994  |
# |    iterations      | 1    |
# |    time_elapsed    | 1    |
# |    total_timesteps | 1024 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 784         |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.013314602 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.0145      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 81.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 723         |
# |    iterations           | 3           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 3072        |
# | train/                  |             |
# |    approx_kl            | 0.013717837 |
# |    clip_fraction        | 0.0785      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0196      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 38.8        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00662    |
# |    value_loss           | 103         |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 4            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0068805385 |
# |    clip_fraction        | 0.039        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.36        |
# |    explained_variance   | 0.00913      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 32.1         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00875     |
# |    value_loss           | 93.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 646         |
# |    iterations           | 5           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 5120        |
# | train/                  |             |
# |    approx_kl            | 0.010313734 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.0235      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.9        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 98.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 6           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.008818558 |
# |    clip_fraction        | 0.0351      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | 0.0152      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.6        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00603    |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.007264762 |
# |    clip_fraction        | 0.0467      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | 0.00208     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 55.9        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 110         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 8           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013978893 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.0558      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0138     |
# |    value_loss           | 67.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 627         |
# |    iterations           | 9           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 9216        |
# | train/                  |             |
# |    approx_kl            | 0.013309891 |
# |    clip_fraction        | 0.138       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.0499      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.8        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 89.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 625         |
# |    iterations           | 10          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008232299 |
# |    clip_fraction        | 0.0683      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.477       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 33.3        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00764    |
# |    value_loss           | 60.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 11          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 11264       |
# | train/                  |             |
# |    approx_kl            | 0.014002312 |
# |    clip_fraction        | 0.112       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.392       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 39.4        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 63.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 12          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011090942 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.555       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.7        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 56.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 13          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 13312       |
# | train/                  |             |
# |    approx_kl            | 0.010153716 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.707       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.3        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 41.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 610         |
# |    iterations           | 14          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.008289637 |
# |    clip_fraction        | 0.0538      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.637       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.7        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00789    |
# |    value_loss           | 59.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 612        |
# |    iterations           | 15         |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 15360      |
# | train/                  |            |
# |    approx_kl            | 0.01039571 |
# |    clip_fraction        | 0.0754     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.23      |
# |    explained_variance   | 0.337      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 22.2       |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.00797   |
# |    value_loss           | 59.5       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 16          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.010488097 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.328       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 42.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 17           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 17408        |
# | train/                  |              |
# |    approx_kl            | 0.0070101866 |
# |    clip_fraction        | 0.0517       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.602        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.5         |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00657     |
# |    value_loss           | 31.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 615         |
# |    iterations           | 18          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009291115 |
# |    clip_fraction        | 0.098       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.521       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.9        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00889    |
# |    value_loss           | 64.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 613         |
# |    iterations           | 19          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 19456       |
# | train/                  |             |
# |    approx_kl            | 0.015918657 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.74        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.6        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 33.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 20          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.007696805 |
# |    clip_fraction        | 0.0421      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.13       |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00727    |
# |    value_loss           | 50          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 603        |
# |    iterations           | 21         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 21504      |
# | train/                  |            |
# |    approx_kl            | 0.00813755 |
# |    clip_fraction        | 0.0395     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.745      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 17.7       |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00629   |
# |    value_loss           | 39.4       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 22           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0063353097 |
# |    clip_fraction        | 0.0286       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14           |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00539     |
# |    value_loss           | 36.7         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 23           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 23552        |
# | train/                  |              |
# |    approx_kl            | 0.0061098738 |
# |    clip_fraction        | 0.0702       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.14        |
# |    explained_variance   | 0.64         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 22.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00707     |
# |    value_loss           | 58.5         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 606          |
# |    iterations           | 24           |
# |    time_elapsed         | 40           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0065964884 |
# |    clip_fraction        | 0.0451       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.11        |
# |    explained_variance   | 0.818        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12           |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00659     |
# |    value_loss           | 34.8         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 607        |
# |    iterations           | 25         |
# |    time_elapsed         | 42         |
# |    total_timesteps      | 25600      |
# | train/                  |            |
# |    approx_kl            | 0.00927634 |
# |    clip_fraction        | 0.0859     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.15      |
# |    explained_variance   | 0.567      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 27.8       |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.00914   |
# |    value_loss           | 58.2       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 608          |
# |    iterations           | 26           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0058096787 |
# |    clip_fraction        | 0.0551       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.663        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 21.6         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00854     |
# |    value_loss           | 43.2         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 27          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.009548635 |
# |    clip_fraction        | 0.075       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.51        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.8        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 37.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 28          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011424165 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.693       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.6         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 20          |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 29           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0077675865 |
# |    clip_fraction        | 0.075        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | 0.658        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.6         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.0108      |
# |    value_loss           | 24.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 30          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009352373 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.619       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.3        |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00752    |
# |    value_loss           | 23.7        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 602          |
# |    iterations           | 31           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 31744        |
# | train/                  |              |
# |    approx_kl            | 0.0057351086 |
# |    clip_fraction        | 0.0366       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.734        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.97         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00683     |
# |    value_loss           | 24           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 604         |
# |    iterations           | 32          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.009269927 |
# |    clip_fraction        | 0.0919      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.798       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.9        |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0116     |
# |    value_loss           | 26.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 605         |
# |    iterations           | 33          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 33792       |
# | train/                  |             |
# |    approx_kl            | 0.007814007 |
# |    clip_fraction        | 0.0624      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.935      |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.6        |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00926    |
# |    value_loss           | 44.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 34          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.013303328 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.989      |
# |    explained_variance   | 0.624       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21.1        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00942    |
# |    value_loss           | 49.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 35           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 35840        |
# | train/                  |              |
# |    approx_kl            | 0.0064070234 |
# |    clip_fraction        | 0.0619       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.98        |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00753     |
# |    value_loss           | 33.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 36          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009271942 |
# |    clip_fraction        | 0.0826      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.921      |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.9        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.01       |
# |    value_loss           | 21.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 37          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 37888       |
# | train/                  |             |
# |    approx_kl            | 0.009933399 |
# |    clip_fraction        | 0.088       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.924      |
# |    explained_variance   | 0.423       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.6        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00731    |
# |    value_loss           | 36.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 38          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012475608 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.982      |
# |    explained_variance   | 0.737       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 25.4        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 39           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 39936        |
# | train/                  |              |
# |    approx_kl            | 0.0064038523 |
# |    clip_fraction        | 0.0383       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.882       |
# |    explained_variance   | 0.544        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.2         |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00582     |
# |    value_loss           | 50.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 604          |
# |    iterations           | 40           |
# |    time_elapsed         | 67           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0073648407 |
# |    clip_fraction        | 0.045        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.943       |
# |    explained_variance   | 0.702        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 17.6         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00899     |
# |    value_loss           | 34.8         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 603        |
# |    iterations           | 41         |
# |    time_elapsed         | 69         |
# |    total_timesteps      | 41984      |
# | train/                  |            |
# |    approx_kl            | 0.00863236 |
# |    clip_fraction        | 0.0551     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.929     |
# |    explained_variance   | 0.697      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 11.9       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00371   |
# |    value_loss           | 27.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 42          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008689266 |
# |    clip_fraction        | 0.0756      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.897      |
# |    explained_variance   | 0.434       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.45        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.00849    |
# |    value_loss           | 24.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 600          |
# |    iterations           | 43           |
# |    time_elapsed         | 73           |
# |    total_timesteps      | 44032        |
# | train/                  |              |
# |    approx_kl            | 0.0057791146 |
# |    clip_fraction        | 0.0357       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.942       |
# |    explained_variance   | 0.554        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14           |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00586     |
# |    value_loss           | 40.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 44          |
# |    time_elapsed         | 74          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.014800342 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.949      |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.1        |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 31.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 45          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 46080       |
# | train/                  |             |
# |    approx_kl            | 0.004809332 |
# |    clip_fraction        | 0.0333      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.991      |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0048     |
# |    value_loss           | 33.5        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 46           |
# |    time_elapsed         | 78           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0076524094 |
# |    clip_fraction        | 0.0737       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.815       |
# |    explained_variance   | 0.548        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.9         |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.0064      |
# |    value_loss           | 34           |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 47          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 48128       |
# | train/                  |             |
# |    approx_kl            | 0.010043908 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.841      |
# |    explained_variance   | 0.507       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 45.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 603         |
# |    iterations           | 48          |
# |    time_elapsed         | 81          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.009635315 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18          |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00577    |
# |    value_loss           | 36          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 49          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 50176       |
# | train/                  |             |
# |    approx_kl            | 0.007146512 |
# |    clip_fraction        | 0.062       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.915      |
# |    explained_variance   | 0.713       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.8        |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00622    |
# |    value_loss           | 26.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 50           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0064094993 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.877       |
# |    explained_variance   | 0.593        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.63         |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.0063      |
# |    value_loss           | 26           |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 600        |
# |    iterations           | 51         |
# |    time_elapsed         | 86         |
# |    total_timesteps      | 52224      |
# | train/                  |            |
# |    approx_kl            | 0.01008273 |
# |    clip_fraction        | 0.0975     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.795     |
# |    explained_variance   | 0.43       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.46       |
# |    n_updates            | 500        |
# |    policy_gradient_loss | -0.0104    |
# |    value_loss           | 26.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 52          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009283904 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.913      |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.8        |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 23.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 601         |
# |    iterations           | 53          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 54272       |
# | train/                  |             |
# |    approx_kl            | 0.009577735 |
# |    clip_fraction        | 0.0716      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.962      |
# |    explained_variance   | 0.627       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.4        |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 33.6        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 602        |
# |    iterations           | 54         |
# |    time_elapsed         | 91         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.00751694 |
# |    clip_fraction        | 0.0391     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.851     |
# |    explained_variance   | 0.31       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.49       |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.00651   |
# |    value_loss           | 28.2       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 603          |
# |    iterations           | 55           |
# |    time_elapsed         | 93           |
# |    total_timesteps      | 56320        |
# | train/                  |              |
# |    approx_kl            | 0.0047001066 |
# |    clip_fraction        | 0.0422       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.869       |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00889     |
# |    value_loss           | 35.5         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 56          |
# |    time_elapsed         | 95          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.009824752 |
# |    clip_fraction        | 0.0813      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.89       |
# |    explained_variance   | 0.699       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.85        |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 24.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 598         |
# |    iterations           | 57          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 58368       |
# | train/                  |             |
# |    approx_kl            | 0.017253788 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.854      |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.8        |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 25.7        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 599        |
# |    iterations           | 58         |
# |    time_elapsed         | 99         |
# |    total_timesteps      | 59392      |
# | train/                  |            |
# |    approx_kl            | 0.01240021 |
# |    clip_fraction        | 0.0878     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.898     |
# |    explained_variance   | 0.402      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 5.59       |
# |    n_updates            | 570        |
# |    policy_gradient_loss | -0.008     |
# |    value_loss           | 17.9       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 59          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 60416       |
# | train/                  |             |
# |    approx_kl            | 0.009446813 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.911      |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 17.1        |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0111     |
# |    value_loss           | 26.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 60          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.008640526 |
# |    clip_fraction        | 0.0637      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.943      |
# |    explained_variance   | 0.635       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.2         |
# |    n_updates            | 590         |
# |    policy_gradient_loss | -0.00597    |
# |    value_loss           | 18.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 600         |
# |    iterations           | 61          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 62464       |
# | train/                  |             |
# |    approx_kl            | 0.008028559 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.512       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.11        |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00916    |
# |    value_loss           | 21.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 601          |
# |    iterations           | 62           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0077738487 |
# |    clip_fraction        | 0.0998       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.838       |
# |    explained_variance   | 0.648        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.14         |
# |    n_updates            | 610          |
# |    policy_gradient_loss | -0.00926     |
# |    value_loss           | 17.9         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 63          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 64512       |
# | train/                  |             |
# |    approx_kl            | 0.010341407 |
# |    clip_fraction        | 0.0424      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.754      |
# |    explained_variance   | 0.502       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.78        |
# |    n_updates            | 620         |
# |    policy_gradient_loss | -0.00828    |
# |    value_loss           | 30.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 597         |
# |    iterations           | 64          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008232941 |
# |    clip_fraction        | 0.0488      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.881      |
# |    explained_variance   | 0.531       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.59        |
# |    n_updates            | 630         |
# |    policy_gradient_loss | -0.00806    |
# |    value_loss           | 26.2        |
# ...
# |    value_loss           | 14.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 159         |
# |    time_elapsed         | 273         |
# |    total_timesteps      | 162816      |
# | train/                  |             |
# |    approx_kl            | 0.008792784 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.49       |
# |    explained_variance   | 0.509       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.99        |
# |    n_updates            | 1580        |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 13          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 595        |
# |    iterations           | 160        |
# |    time_elapsed         | 275        |
# |    total_timesteps      | 163840     |
# | train/                  |            |
# |    approx_kl            | 0.01003107 |
# |    clip_fraction        | 0.0987     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.438     |
# |    explained_variance   | 0.436      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.42       |
# |    n_updates            | 1590       |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 12.7       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 161         |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 164864      |
# | train/                  |             |
# |    approx_kl            | 0.009999341 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.431       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.36        |
# |    n_updates            | 1600        |
# |    policy_gradient_loss | -0.00816    |
# |    value_loss           | 9.46        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 162         |
# |    time_elapsed         | 278         |
# |    total_timesteps      | 165888      |
# | train/                  |             |
# |    approx_kl            | 0.010868471 |
# |    clip_fraction        | 0.0824      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.418      |
# |    explained_variance   | 0.461       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.32        |
# |    n_updates            | 1610        |
# |    policy_gradient_loss | -0.00809    |
# |    value_loss           | 10.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 163         |
# |    time_elapsed         | 280         |
# |    total_timesteps      | 166912      |
# | train/                  |             |
# |    approx_kl            | 0.015170866 |
# |    clip_fraction        | 0.115       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.442      |
# |    explained_variance   | 0.451       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.36        |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | -0.0204     |
# |    value_loss           | 9.94        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 164         |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.013902829 |
# |    clip_fraction        | 0.0866      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.459      |
# |    explained_variance   | 0.492       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.77        |
# |    n_updates            | 1630        |
# |    policy_gradient_loss | -0.00913    |
# |    value_loss           | 7.93        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 165         |
# |    time_elapsed         | 283         |
# |    total_timesteps      | 168960      |
# | train/                  |             |
# |    approx_kl            | 0.008096352 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.404      |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.92        |
# |    n_updates            | 1640        |
# |    policy_gradient_loss | -0.00999    |
# |    value_loss           | 12.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 166         |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.009342467 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.426      |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.53        |
# |    n_updates            | 1650        |
# |    policy_gradient_loss | -0.0196     |
# |    value_loss           | 11.9        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 167          |
# |    time_elapsed         | 287          |
# |    total_timesteps      | 171008       |
# | train/                  |              |
# |    approx_kl            | 0.0071900757 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.378       |
# |    explained_variance   | 0.332        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.31         |
# |    n_updates            | 1660         |
# |    policy_gradient_loss | -0.00989     |
# |    value_loss           | 16.7         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 168         |
# |    time_elapsed         | 288         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.010198471 |
# |    clip_fraction        | 0.0794      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.404      |
# |    explained_variance   | 0.382       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.15        |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 12.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 595          |
# |    iterations           | 169          |
# |    time_elapsed         | 290          |
# |    total_timesteps      | 173056       |
# | train/                  |              |
# |    approx_kl            | 0.0050806124 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.369       |
# |    explained_variance   | 0.373        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.24         |
# |    n_updates            | 1680         |
# |    policy_gradient_loss | -0.00414     |
# |    value_loss           | 10.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 170         |
# |    time_elapsed         | 292         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.019779038 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.363      |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.39        |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.0261     |
# |    value_loss           | 20.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 171         |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 175104      |
# | train/                  |             |
# |    approx_kl            | 0.009867729 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.4        |
# |    explained_variance   | 0.341       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.57        |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 15.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 172         |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.009709792 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.393      |
# |    explained_variance   | 0.466       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.55        |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | -0.00989    |
# |    value_loss           | 10.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 173         |
# |    time_elapsed         | 297         |
# |    total_timesteps      | 177152      |
# | train/                  |             |
# |    approx_kl            | 0.006566592 |
# |    clip_fraction        | 0.0578      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.352      |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.27        |
# |    n_updates            | 1720        |
# |    policy_gradient_loss | -0.00778    |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 594         |
# |    iterations           | 174         |
# |    time_elapsed         | 299         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.012505915 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.41       |
# |    explained_variance   | 0.582       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.11        |
# |    n_updates            | 1730        |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 7           |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 175         |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 179200      |
# | train/                  |             |
# |    approx_kl            | 0.009624352 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | 0.363       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.66        |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | -0.00928    |
# |    value_loss           | 18.5        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 595        |
# |    iterations           | 176        |
# |    time_elapsed         | 302        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.00857388 |
# |    clip_fraction        | 0.0878     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.372     |
# |    explained_variance   | 0.433      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.69       |
# |    n_updates            | 1750       |
# |    policy_gradient_loss | -0.00892   |
# |    value_loss           | 7.14       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 177         |
# |    time_elapsed         | 304         |
# |    total_timesteps      | 181248      |
# | train/                  |             |
# |    approx_kl            | 0.008000723 |
# |    clip_fraction        | 0.0783      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.98        |
# |    n_updates            | 1760        |
# |    policy_gradient_loss | -0.00649    |
# |    value_loss           | 8.29        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 178         |
# |    time_elapsed         | 305         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.028317982 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.405      |
# |    explained_variance   | 0.435       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.96        |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | -0.0361     |
# |    value_loss           | 19.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 596         |
# |    iterations           | 179         |
# |    time_elapsed         | 307         |
# |    total_timesteps      | 183296      |
# | train/                  |             |
# |    approx_kl            | 0.012997978 |
# |    clip_fraction        | 0.0795      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.37       |
# |    explained_variance   | 0.268       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.12        |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.00826    |
# |    value_loss           | 12.4        |
# -----------------------------------------

# %%
# === Cell 6: Evaluate (plain env) - sanity check ===
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print("Evaluation (mean, std):", mean_reward, std_reward)

obs, info = eval_env.reset()
action, _ = model.predict(obs, deterministic=True)
print("Sample model action:", action)

# %%
# === Cell 7: Visualize a single episode and animate ===
viz_env = WarehouseEnv(grid_size=10)
obs, info = viz_env.reset()

frames = []
terminated = False
truncated = False
steps = 0
max_steps = 300

while not (terminated or truncated) and steps < max_steps:
    action, _ = model.predict(obs, deterministic=True)  # obs is a 1D array
    obs, reward, terminated, truncated, info = viz_env.step(int(action))
    frame = viz_env.render()
    frames.append(frame)
    steps += 1

print("Episode length:", len(frames), "terminated:", terminated, "truncated:", truncated)

fig = plt.figure(figsize=(5,5))
plt.axis("off")
im = plt.imshow(frames[0])

def update(i):
    im.set_data(frames[i])
    return [im]

anim = animation.FuncAnimation(fig, update, frames=len(frames), interval=150, blit=True)
plt.close(fig)
from IPython.display import HTML
HTML(anim.to_jshtml())   # displays animation in Colab / Jupyter
# Out:
# Episode length: 12 terminated: True truncated: False
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgdb6369768106489fba48bf0d5b65c833">
#   <div class="anim-controls">
#     <input id="_anim_sliderdb6369768106489fba48bf0d5b65c833" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animdb6369768106489fba48bf0d5b65c833.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animdb6369768106489fba48bf0d5b65c833.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animdb6369768106489fba48bf0d5b65c833.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animdb6369768106489fba48bf0d5b65c833.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animdb6369768106489fba48bf0d5b65c833.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animdb6369768106489fba48bf0d5b65c833.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animdb6369768106489fba48bf0d5b65c833.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animdb6369768106489fba48bf0d5b65c833.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animdb6369768106489fba48bf0d5b65c833.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animdb6369768106489fba48bf0d5b65c833.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectdb6369768106489fba48bf0d5b65c833"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_db6369768106489fba48bf0d5b65c833"
#              >
#       <label for="_anim_radio1_db6369768106489fba48bf0d5b65c833">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_db6369768106489fba48bf0d5b65c833"
#              checked>
#       <label for="_anim_radio2_db6369768106489fba48bf0d5b65c833">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_db6369768106489fba48bf0d5b65c833"
#              >
#       <label for="_anim_radio3_db6369768106489fba48bf0d5b65c833">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgdb6369768106489fba48bf0d5b65c833";
#     var slider_id = "_anim_sliderdb6369768106489fba48bf0d5b65c833";
#     var loop_select_id = "_anim_loop_selectdb6369768106489fba48bf0d5b65c833";
#     var frames = new Array(12);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjAsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvlHJYcgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAATKZJR
